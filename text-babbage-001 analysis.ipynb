# %%
import numpy as np
import re
import json
import pandas as pd

# %%
model = "text-babbage-001"

labels = pd.read_csv("results.txt", delimiter = ",").loc[:,["pairid", " varA","varB","dataset","groundtruth"]]
labels['pairid'] = labels['pairid'].str.extract('(\d{4})').astype(int) # convert pairid to int
labels["groundtruth"] = labels["groundtruth"].str.replace(r'\s+', '', regex=True) # remove white space in labels

weights = pd.read_csv("pairmeta.txt", delimiter = " ", header = None).iloc[:,[0,5]]
weights.rename(columns = {0:"pairid", 5:"weight"}, inplace=True)
weights['pairid'] = weights['pairid'].astype(int) # convert pairid to int

merged_df = labels.merge(weights, on='pairid')
merged_df["AtoB"] = ""
merged_df["BtoA"] = ""

with open(model + "_response.json", "r") as file:
    loaded_data = json.load(file)
    
merged_df.head()
# Out:
#    pairid       varA            varB  dataset groundtruth  weight AtoB BtoA
# 0       1   Altitude     Temperature      DWD          ->   0.166
# 1       2   Altitude   Precipitation      DWD          ->   0.166
# 2       3  Longitude     Temperature      DWD          ->   0.167
# 3       4   Altitude  Sunshine hours      DWD          ->   0.166
# 4       5        Age          Length  Abalone          ->   0.143

# %%
for i in range(108):
    print(loaded_data[i])
# Out:
# {'pair0001,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5whhUyl0encyusuxyBO3ntKndrW', 'object': 'text_completion', 'created': 1694795219, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the altitude can', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 22, 'completion_tokens': 7, 'total_tokens': 29}}}
# {'pair0001,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5whO5RCUOCQUqnaDT92aGe8UMxF', 'object': 'text_completion', 'created': 1694795219, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 20, 'total_tokens': 20}}}
# {'pair0002,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5whZKzF4trOdMpoxj8DknIPThHq', 'object': 'text_completion', 'created': 1694795219, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the altitude can', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 22, 'completion_tokens': 7, 'total_tokens': 29}}}
# {'pair0002,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5whfP3P0i9f0K53C81CZ9HHPvoW', 'object': 'text_completion', 'created': 1694795219, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, precipitation can cause', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 20, 'completion_tokens': 7, 'total_tokens': 27}}}
# {'pair0003,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wiroPJHfPNy9KYUwDUKAOnpIzR', 'object': 'text_completion', 'created': 1694795220, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 23, 'total_tokens': 23}}}
# {'pair0003,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wiaYlozGp8cmq9cltYwrPCJ6iX', 'object': 'text_completion', 'created': 1694795220, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 21, 'total_tokens': 21}}}
# {'pair0004,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wi5TZsmsSvIxmm9Te0FjbX5HM7', 'object': 'text_completion', 'created': 1694795220, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the altitude can', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 23, 'completion_tokens': 7, 'total_tokens': 30}}}
# {'pair0004,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wifzX0jXRwhMW6umWe1FPBh3JZ', 'object': 'text_completion', 'created': 1694795220, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, changing sunlight hours', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 21, 'completion_tokens': 7, 'total_tokens': 28}}}
# {'pair0005,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wipKylZcKITdKBnP918sh1urN7', 'object': 'text_completion', 'created': 1694795220, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, abalone can', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 7, 'total_tokens': 37}}}
# {'pair0005,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wi9pmTeF1Eqe94camodamKFAVP', 'object': 'text_completion', 'created': 1694795220, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 22, 'total_tokens': 22}}}
# {'pair0006,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wiWxtnXUj8HYRIBobp6kv5Bl8q', 'object': 'text_completion', 'created': 1694795220, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, abalone shells', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 31, 'completion_tokens': 7, 'total_tokens': 38}}}
# {'pair0006,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wjIhHZOx5sORoSFB0NDCcJcj98', 'object': 'text_completion', 'created': 1694795221, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 23, 'total_tokens': 23}}}
# {'pair0007,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wjTo3HesaNGy7SFLAsXxcQDroP', 'object': 'text_completion', 'created': 1694795221, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, abalone at', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 7, 'total_tokens': 37}}}
# {'pair0007,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wjcdsyAbiNVH32LF4jHGUYRDqT', 'object': 'text_completion', 'created': 1694795221, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 22, 'total_tokens': 22}}}
# {'pair0008,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wjADBLNgwpSlDWn1nrBaFPp1P9', 'object': 'text_completion', 'created': 1694795221, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, abalone at', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 7, 'total_tokens': 37}}}
# {'pair0008,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wj9fWwdCdX3P1rajmY0XD5gPMZ', 'object': 'text_completion', 'created': 1694795221, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 22, 'total_tokens': 22}}}
# {'pair0009,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wjAqXEry1r99Io1ZIC50nugqZx', 'object': 'text_completion', 'created': 1694795221, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 31, 'total_tokens': 31}}}
# {'pair0009,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wk282dNvaD2XIlF2ycuiNthgQ9', 'object': 'text_completion', 'created': 1694795222, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 23, 'total_tokens': 23}}}
# {'pair0010,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wkrUVsQzx7BGuaGZKdKo2THc0Q', 'object': 'text_completion', 'created': 1694795222, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the shucked', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 32, 'completion_tokens': 7, 'total_tokens': 39}}}
# {'pair0010,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wkb6ptB4jx84cwPUxouENGX8yt', 'object': 'text_completion', 'created': 1694795222, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, a change in', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 24, 'completion_tokens': 7, 'total_tokens': 31}}}
# {'pair0011,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wkM8GQvo2Lta3WZt2YRgQhAjCf', 'object': 'text_completion', 'created': 1694795222, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, abalone changes', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 33, 'completion_tokens': 7, 'total_tokens': 40}}}
# {'pair0011,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wkw2R4F22tcgdmYgM0dIGNq7Dv', 'object': 'text_completion', 'created': 1694795222, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, a change in', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 25, 'completion_tokens': 7, 'total_tokens': 32}}}
# {'pair0012,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wk3ULyd7fsLOYlDnXTGZgSsxwd', 'object': 'text_completion', 'created': 1694795222, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 30, 'total_tokens': 30}}}
# {'pair0012,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wlE4f1HNedCRnAkSPNVwwmGsqz', 'object': 'text_completion', 'created': 1694795223, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, if the wage', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 24, 'completion_tokens': 7, 'total_tokens': 31}}}
# {'pair0013,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wlpkQXKWF4FdSmMYhboP6BwLQs', 'object': 'text_completion', 'created': 1694795223, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, displacement of a', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 7, 'total_tokens': 36}}}
# {'pair0013,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wlLBvgCbqrqcXOzRzYoG5c4saM', 'object': 'text_completion', 'created': 1694795223, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 23, 'completion_tokens': 3, 'total_tokens': 26}}}
# {'pair0014,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wlT8Kwg9AeYec1symurnPDEjvl', 'object': 'text_completion', 'created': 1694795223, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the horse power', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 7, 'total_tokens': 37}}}
# {'pair0014,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wlfIGTPqDJzJ1Xm3iaWHISnuH0', 'object': 'text_completion', 'created': 1694795223, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, a change in', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 24, 'completion_tokens': 7, 'total_tokens': 31}}}
# {'pair0015,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wm11afKKu0d9py2orz1MWC8KAF', 'object': 'text_completion', 'created': 1694795224, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the weight of', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 7, 'total_tokens': 36}}}
# {'pair0015,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wmO7gEfuZHjOQUxVza8SwFfHjW', 'object': 'text_completion', 'created': 1694795224, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, a change in', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 23, 'completion_tokens': 7, 'total_tokens': 30}}}
# {'pair0016,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wmN8oVCiZuXtmUkNKBj8QRdzq0', 'object': 'text_completion', 'created': 1694795224, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 29, 'total_tokens': 29}}}
# {'pair0016,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wmNsf6ixG9MH2ELhg00NWDIOln', 'object': 'text_completion', 'created': 1694795224, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the horse power', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 23, 'completion_tokens': 7, 'total_tokens': 30}}}
# {'pair0017,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wm7jHRHE4sVSERZdZ5O6DGNPr3', 'object': 'text_completion', 'created': 1694795224, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 30, 'total_tokens': 30}}}
# {'pair0017,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wnKC3Tw0tbvOTteMzdzNzI0GAL', 'object': 'text_completion', 'created': 1694795225, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 24, 'completion_tokens': 3, 'total_tokens': 27}}}
# {'pair0018,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wnQTmC91hUJVxyl8MQXMuULbpT', 'object': 'text_completion', 'created': 1694795225, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the concentration of', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 7, 'total_tokens': 37}}}
# {'pair0018,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wnHtpbn8NIL01XQJfHZe1W2kGB', 'object': 'text_completion', 'created': 1694795225, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 24, 'completion_tokens': 3, 'total_tokens': 27}}}
# {'pair0019,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wnKdaI7MvR9IrB4U6LqVHo2Wce', 'object': 'text_completion', 'created': 1694795225, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 39, 'total_tokens': 39}}}
# {'pair0019,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wnxIiqDnpd38Xhl1zcKO47ytTn', 'object': 'text_completion', 'created': 1694795225, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 3, 'total_tokens': 32}}}
# {'pair0020,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wnQIiK0VJMrdqo5INxRtTUTk0S', 'object': 'text_completion', 'created': 1694795225, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, latitude can affect', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 22, 'completion_tokens': 7, 'total_tokens': 29}}}
# {'pair0020,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5woTTCWZzWTNvMm8yL1vJAwFNuI', 'object': 'text_completion', 'created': 1694795226, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 20, 'total_tokens': 20}}}
# {'pair0021,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wojxyonlm2SpgltYU9ctKfGItq', 'object': 'text_completion', 'created': 1694795226, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the longitude', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 23, 'completion_tokens': 7, 'total_tokens': 30}}}
# {'pair0021,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5woAxConHS6InL1wYgqhfSsC6p8', 'object': 'text_completion', 'created': 1694795226, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 21, 'completion_tokens': 3, 'total_tokens': 24}}}
# {'pair0022,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wpquykJIzB8YYoAmV7rT4L6X56', 'object': 'text_completion', 'created': 1694795227, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 28, 'total_tokens': 28}}}
# {'pair0022,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wqG3AKM7XoDKJaWwxUsijiGQPt', 'object': 'text_completion', 'created': 1694795228, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, there is a', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 22, 'completion_tokens': 7, 'total_tokens': 29}}}
# {'pair0023,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wqFoJy2dmOrpnRZ8JrTUXUz64f', 'object': 'text_completion', 'created': 1694795228, 'model': 'text-babbage-001', 'choices': [{'text': "\n\nYes, a person's", 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 28, 'completion_tokens': 7, 'total_tokens': 35}}}
# {'pair0023,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wqZD5laG5Qy7iHMvQRE9RwHVqx', 'object': 'text_completion', 'created': 1694795228, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, weight can affect', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 22, 'completion_tokens': 7, 'total_tokens': 29}}}
# {'pair0024,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wrCFLzQyQvdSuRrbqZgVPHdrAy', 'object': 'text_completion', 'created': 1694795229, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 29, 'total_tokens': 29}}}
# {'pair0024,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wrw1iyKssmuloYsDmprmMOHii1', 'object': 'text_completion', 'created': 1694795229, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 23, 'completion_tokens': 3, 'total_tokens': 26}}}
# {'pair0025,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wrviAvWujDsfypfXz7oEmuE5dy', 'object': 'text_completion', 'created': 1694795229, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 7, 'total_tokens': 37}}}
# {'pair0025,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wr9M7CqMV2MkQWhbutk4FlfHvX', 'object': 'text_completion', 'created': 1694795229, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, a change in', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 28, 'completion_tokens': 7, 'total_tokens': 35}}}
# {'pair0026,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wrCrYMEKsLtJfZLzzlat4abBNA', 'object': 'text_completion', 'created': 1694795229, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, blast furnace sl', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 33, 'completion_tokens': 7, 'total_tokens': 40}}}
# {'pair0026,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wrsG31VPVj3opqvSWNoMbisZSq', 'object': 'text_completion', 'created': 1694795229, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 31, 'completion_tokens': 7, 'total_tokens': 38}}}
# {'pair0027,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wrHu5ULWV0nd5m91DJJQzfLxgB', 'object': 'text_completion', 'created': 1694795229, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, fly ash can', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 31, 'completion_tokens': 7, 'total_tokens': 38}}}
# {'pair0027,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wsZFfAXIK9AwfnwSuRzhDbk5UG', 'object': 'text_completion', 'created': 1694795230, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, fly ash changes', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 7, 'total_tokens': 36}}}
# {'pair0028,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wsMrSPsRagYAvF2xfLid0L8HAE', 'object': 'text_completion', 'created': 1694795230, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 7, 'total_tokens': 37}}}
# {'pair0028,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wscMkYP2o6ecLbKkPXcmr8lleO', 'object': 'text_completion', 'created': 1694795230, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 28, 'completion_tokens': 7, 'total_tokens': 35}}}
# {'pair0029,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wsdyKZENKNpVRF9dgYwsYVyYFe', 'object': 'text_completion', 'created': 1694795230, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 33, 'completion_tokens': 7, 'total_tokens': 40}}}
# {'pair0029,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5ws5oAeqVZE9hhfYiBMZx84mrqP', 'object': 'text_completion', 'created': 1694795230, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 31, 'completion_tokens': 7, 'total_tokens': 38}}}
# {'pair0030,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wsufUkdqRXwlGxbfZG3ovAhgVT', 'object': 'text_completion', 'created': 1694795230, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the amount of', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 31, 'completion_tokens': 7, 'total_tokens': 38}}}
# {'pair0030,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wtqtqMoUQiP74UYZieRe8xW1na', 'object': 'text_completion', 'created': 1694795231, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 7, 'total_tokens': 36}}}
# {'pair0031,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wtHOjbqPAvGa1T0iFqSe9ULVV6', 'object': 'text_completion', 'created': 1694795231, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 31, 'completion_tokens': 7, 'total_tokens': 38}}}
# {'pair0031,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wtPgLqBjkRf3ygWRQ1VAderd9M', 'object': 'text_completion', 'created': 1694795231, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 7, 'total_tokens': 36}}}
# {'pair0032,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wtMAMRoVci7i9Gb3ywZBj98Fdl', 'object': 'text_completion', 'created': 1694795231, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the compressive', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 28, 'completion_tokens': 7, 'total_tokens': 35}}}
# {'pair0032,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wtaoNmhyjkWzDLkTFUJSmXprRa', 'object': 'text_completion', 'created': 1694795231, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, a change in', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 24, 'completion_tokens': 7, 'total_tokens': 31}}}
# {'pair0033,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wtyTxlaPBy2Uhins7HuymOt1OE', 'object': 'text_completion', 'created': 1694795231, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 34, 'total_tokens': 34}}}
# {'pair0033,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wuZ31hg0cir8bdHKQapGrjToTL', 'object': 'text_completion', 'created': 1694795232, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 28, 'completion_tokens': 3, 'total_tokens': 31}}}
# {'pair0034,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wuaMWk61lGvQvTBpCdiWalbLOO', 'object': 'text_completion', 'created': 1694795232, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 35, 'completion_tokens': 3, 'total_tokens': 38}}}
# {'pair0034,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wuj0RDoOfgd12dnQEZFecp2xgg', 'object': 'text_completion', 'created': 1694795232, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 3, 'total_tokens': 32}}}
# {'pair0035,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wuWVX2zbEHCPY5OMpgJJ3uHXUv', 'object': 'text_completion', 'created': 1694795232, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 39, 'completion_tokens': 3, 'total_tokens': 42}}}
# {'pair0035,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wuOP5luMoCUrP2S1Akn4eJMagj', 'object': 'text_completion', 'created': 1694795232, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 33, 'completion_tokens': 3, 'total_tokens': 36}}}
# {'pair0036,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wu7ZIQuEWGXp34hbOXM7sWIc1g', 'object': 'text_completion', 'created': 1694795232, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 39, 'completion_tokens': 3, 'total_tokens': 42}}}
# {'pair0036,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wuO5jtJTGrjesVHxdyMYfwzo9D', 'object': 'text_completion', 'created': 1694795232, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 33, 'completion_tokens': 3, 'total_tokens': 36}}}
# {'pair0037,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wvbhNCgrbsMwACGN3XM3BvWh88', 'object': 'text_completion', 'created': 1694795233, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 41, 'completion_tokens': 3, 'total_tokens': 44}}}
# {'pair0037,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wvjF0b5tSYWLCkp55Zb6Fh3BzS', 'object': 'text_completion', 'created': 1694795233, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 35, 'completion_tokens': 3, 'total_tokens': 38}}}
# {'pair0038,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wvXYo0qevnJYun12Y7PGoEZcvG', 'object': 'text_completion', 'created': 1694795233, 'model': 'text-babbage-001', 'choices': [{'text': "\n\nYes, a person's", 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 7, 'total_tokens': 37}}}
# {'pair0038,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wvSSme3B8vv35CNvgMWFEG7A86', 'object': 'text_completion', 'created': 1694795233, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 24, 'completion_tokens': 3, 'total_tokens': 27}}}
# {'pair0039,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wvjvFrBENsUBM0R7X2ClAqVlql', 'object': 'text_completion', 'created': 1694795233, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, there is a', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 7, 'total_tokens': 36}}}
# {'pair0039,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wvePEocaQB31akln1owaFpnmuo', 'object': 'text_completion', 'created': 1694795233, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 23, 'completion_tokens': 3, 'total_tokens': 26}}}
# {'pair0040,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wvCSb3RdP9pBDkmQYKjwbwrZgl', 'object': 'text_completion', 'created': 1694795233, 'model': 'text-babbage-001', 'choices': [{'text': "\n\nYes, a person's", 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 32, 'completion_tokens': 7, 'total_tokens': 39}}}
# {'pair0040,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5ww5tbLBAHWJMjLOqC0SyOGiydR', 'object': 'text_completion', 'created': 1694795234, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 26, 'total_tokens': 26}}}
# {'pair0041,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wwPOyuZAY7w242LLsiYjkevb6H', 'object': 'text_completion', 'created': 1694795234, 'model': 'text-babbage-001', 'choices': [{'text': "\n\nYes, a person's", 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 7, 'total_tokens': 37}}}
# {'pair0041,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wweZsl8xGjKkuYRl7hrtYFeuLM', 'object': 'text_completion', 'created': 1694795234, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 24, 'completion_tokens': 3, 'total_tokens': 27}}}
# {'pair0042,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wwDXOKpq1xgDcEdgtpg7cHHzMn', 'object': 'text_completion', 'created': 1694795234, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the temperature can', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 25, 'completion_tokens': 7, 'total_tokens': 32}}}
# {'pair0042,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5ww1a7BZTtzZ48DP2pZ8PRP0coi', 'object': 'text_completion', 'created': 1694795234, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 25, 'completion_tokens': 3, 'total_tokens': 28}}}
# {'pair0043,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wwPOITC3Lm10VFvtNcsAYsyx2T', 'object': 'text_completion', 'created': 1694795234, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 3, 'total_tokens': 33}}}
# {'pair0043,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wwAS634A33Aub2MrvMPXP9q4R7', 'object': 'text_completion', 'created': 1694795234, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 3, 'total_tokens': 33}}}
# {'pair0044,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wxiUKG5XlSOCpdufFD1OjaIbqo', 'object': 'text_completion', 'created': 1694795235, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 3, 'total_tokens': 33}}}
# {'pair0044,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wx3ndFhoYim1xveFMvq8GDUy0I', 'object': 'text_completion', 'created': 1694795235, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 30, 'completion_tokens': 3, 'total_tokens': 33}}}
# {'pair0045,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wx1sr5vtMLKeTYKwXIpxWoBCzp', 'object': 'text_completion', 'created': 1694795235, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 34, 'completion_tokens': 3, 'total_tokens': 37}}}
# {'pair0045,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wxQwcNawqoh2hxSkEnAY0sZnxu', 'object': 'text_completion', 'created': 1694795235, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 34, 'completion_tokens': 3, 'total_tokens': 37}}}
# {'pair0046,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wxZgQ4c2QFySyDFabsOlYmJNTb', 'object': 'text_completion', 'created': 1694795235, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 32, 'total_tokens': 32}}}
# {'pair0046,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wxT1jSLliR5pYc9sqiF0w2aZWJ', 'object': 'text_completion', 'created': 1694795235, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 32, 'completion_tokens': 3, 'total_tokens': 35}}}
# {'pair0047,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wxUcYt063VQxSxitv4oDApD20h', 'object': 'text_completion', 'created': 1694795235, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the number of', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 28, 'completion_tokens': 7, 'total_tokens': 35}}}
# {'pair0047,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wy2iSS7DFtAKVUGLoKqTKi5E0c', 'object': 'text_completion', 'created': 1694795236, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, the change in', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 28, 'completion_tokens': 7, 'total_tokens': 35}}}
# {'pair0048,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wySqqEcIP0uogjN6pZuaMhfRRr', 'object': 'text_completion', 'created': 1694795236, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 24, 'total_tokens': 24}}}
# {'pair0048,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wyRQafa4KgwGjwHI9IRcp9sS1s', 'object': 'text_completion', 'created': 1694795236, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 22, 'total_tokens': 22}}}
# {'pair0049,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wyBfI9Nb6fGbgImuuphKjtPYjP', 'object': 'text_completion', 'created': 1694795236, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 48, 'total_tokens': 48}}}
# {'pair0049,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wy6Tiq6G0KgO88NU8mbFsX0fRw', 'object': 'text_completion', 'created': 1694795236, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 26, 'completion_tokens': 3, 'total_tokens': 29}}}
# {'pair0050,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wysxl5cxnMrsqLLVCGkPGLX4NJ', 'object': 'text_completion', 'created': 1694795236, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 36, 'total_tokens': 36}}}
# {'pair0050,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wzjnNzseftSfjL814EQpcOjUFC', 'object': 'text_completion', 'created': 1694795237, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 26, 'completion_tokens': 3, 'total_tokens': 29}}}
# {'pair0051,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wzKsVpNiJLxcTxTIh7q3zpyZpU', 'object': 'text_completion', 'created': 1694795237, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 38, 'total_tokens': 38}}}
# {'pair0051,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wz5dHJZtywVrLHe9vgbVYmnRXS', 'object': 'text_completion', 'created': 1694795237, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 26, 'completion_tokens': 3, 'total_tokens': 29}}}
# {'pair0052,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wzzcquNr6fM2UHHGprCZ8armrG', 'object': 'text_completion', 'created': 1694795237, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 54, 'completion_tokens': 3, 'total_tokens': 57}}}
# {'pair0052,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wz77iWSQ0nb04hEfIphlgZl2nF', 'object': 'text_completion', 'created': 1694795237, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 54, 'completion_tokens': 3, 'total_tokens': 57}}}
# {'pair0053,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wzNp4qQsMVJWAqDH7wmMdWXIhC', 'object': 'text_completion', 'created': 1694795237, 'model': 'text-babbage-001', 'choices': [{'text': '', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 26, 'total_tokens': 26}}}
# {'pair0053,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5wzq5MmlsX2muCPoDgrwzFu3ufE', 'object': 'text_completion', 'created': 1694795237, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes', 'index': 0, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 26, 'completion_tokens': 3, 'total_tokens': 29}}}
# {'pair0054,_res1': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5x0G7U5hNObZJ52G8KSG9kzrZ4D', 'object': 'text_completion', 'created': 1694795238, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, displacement, horsepower', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 7, 'total_tokens': 36}}}
# {'pair0054,_res2': {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations', 'id': 'cmpl-7z5x0zk796TlmqsJVJSkJr17vMln0', 'object': 'text_completion', 'created': 1694795238, 'model': 'text-babbage-001', 'choices': [{'text': '\n\nYes, a change in', 'index': 0, 'logprobs': None, 'finish_reason': 'length'}], 'usage': {'prompt_tokens': 29, 'completion_tokens': 7, 'total_tokens': 36}}}

# %%
def add_prediction(merged_df, loaded_data, model):
    merged_df = merged_df.set_index('pairid')
    for response in loaded_data:
        pairid, resid, answer = extract_answers(response)
        print(pairid,resid, answer)
        col = "AtoB" if resid == "1" else "BtoA"
        merged_df.loc[int(pairid),col] = "Yes" if answer[:3] == "Yes" else "No" if answer == "" else ">>>>??"
        print("Converted:", merged_df.loc[int(pairid),col])
    return merged_df


def extract_answers(s):
    # Compile regex patterns
    
    pairid_pattern = re.compile(r"\{'pair0(\d{3}),_res(\d)")
    
    # Search for pairid
    pairid_match = pairid_pattern.search(str(s))
    pairid = pairid_match.group(1) if pairid_match else None
    resid = pairid_match.group(2) if pairid_match else None
    
    # Search for answer
    ans = s["pair0"+ str(pairid) + ',_res' + str(resid)]["choices"][0]["text"]
    
    return pairid, resid, ans[2:]

# %%
results = add_prediction(merged_df, loaded_data, model)
# Out:
# 001 1 Yes, the altitude can
# Converted: Yes
# 001 2
# Converted: No
# 002 1 Yes, the altitude can
# Converted: Yes
# 002 2 Yes, precipitation can cause
# Converted: Yes
# 003 1
# Converted: No
# 003 2
# Converted: No
# 004 1 Yes, the altitude can
# Converted: Yes
# 004 2 Yes, changing sunlight hours
# Converted: Yes
# 005 1 Yes, abalone can
# Converted: Yes
# 005 2
# Converted: No
# 006 1 Yes, abalone shells
# Converted: Yes
# 006 2
# Converted: No
# 007 1 Yes, abalone at
# Converted: Yes
# 007 2
# Converted: No
# 008 1 Yes, abalone at
# Converted: Yes
# 008 2
# Converted: No
# 009 1
# Converted: No
# 009 2
# Converted: No
# 010 1 Yes, the shucked
# Converted: Yes
# 010 2 Yes, a change in
# Converted: Yes
# 011 1 Yes, abalone changes
# Converted: Yes
# 011 2 Yes, a change in
# Converted: Yes
# 012 1
# Converted: No
# 012 2 Yes, if the wage
# Converted: Yes
# 013 1 Yes, displacement of a
# Converted: Yes
# 013 2 Yes
# Converted: Yes
# 014 1 Yes, the horse power
# Converted: Yes
# 014 2 Yes, a change in
# Converted: Yes
# 015 1 Yes, the weight of
# Converted: Yes
# 015 2 Yes, a change in
# Converted: Yes
# 016 1
# Converted: No
# 016 2 Yes, the horse power
# Converted: Yes
# 017 1
# Converted: No
# 017 2 Yes
# Converted: Yes
# 018 1 Yes, the concentration of
# Converted: Yes
# 018 2 Yes
# Converted: Yes
# 019 1
# Converted: No
# 019 2 Yes
# Converted: Yes
# 020 1 Yes, latitude can affect
# Converted: Yes
# 020 2
# Converted: No
# 021 1 Yes, the longitude
# Converted: Yes
# 021 2 Yes
# Converted: Yes
# 022 1
# Converted: No
# 022 2 Yes, there is a
# Converted: Yes
# 023 1 Yes, a person's
# Converted: Yes
# 023 2 Yes, weight can affect
# Converted: Yes
# 024 1
# Converted: No
# 024 2 Yes
# Converted: Yes
# 025 1 Yes, the compressive
# Converted: Yes
# 025 2 Yes, a change in
# Converted: Yes
# 026 1 Yes, blast furnace sl
# Converted: Yes
# 026 2 Yes, the compressive
# Converted: Yes
# 027 1 Yes, fly ash can
# Converted: Yes
# 027 2 Yes, fly ash changes
# Converted: Yes
# 028 1 Yes, the compressive
# Converted: Yes
# 028 2 Yes, the compressive
# Converted: Yes
# 029 1 Yes, the compressive
# Converted: Yes
# 029 2 Yes, the compressive
# Converted: Yes
# 030 1 Yes, the amount of
# Converted: Yes
# 030 2 Yes, the compressive
# Converted: Yes
# 031 1 Yes, the compressive
# Converted: Yes
# 031 2 Yes, the compressive
# Converted: Yes
# 032 1 Yes, the compressive
# Converted: Yes
# 032 2 Yes, a change in
# Converted: Yes
# 033 1
# Converted: No
# 033 2 Yes
# Converted: Yes
# 034 1 Yes
# Converted: Yes
# 034 2 Yes
# Converted: Yes
# 035 1 Yes
# Converted: Yes
# 035 2 Yes
# Converted: Yes
# 036 1 Yes
# Converted: Yes
# 036 2 Yes
# Converted: Yes
# 037 1 Yes
# Converted: Yes
# 037 2 Yes
# Converted: Yes
# 038 1 Yes, a person's
# Converted: Yes
# 038 2 Yes
# Converted: Yes
# 039 1 Yes, there is a
# Converted: Yes
# 039 2 Yes
# Converted: Yes
# 040 1 Yes, a person's
# Converted: Yes
# 040 2
# Converted: No
# 041 1 Yes, a person's
# Converted: Yes
# 041 2 Yes
# Converted: Yes
# 042 1 Yes, the temperature can
# Converted: Yes
# 042 2 Yes
# Converted: Yes
# 043 1 Yes
# Converted: Yes
# 043 2 Yes
# Converted: Yes
# 044 1 Yes
# Converted: Yes
# 044 2 Yes
# Converted: Yes
# 045 1 Yes
# Converted: Yes
# 045 2 Yes
# Converted: Yes
# 046 1
# Converted: No
# 046 2 Yes
# Converted: Yes
# 047 1 Yes, the number of
# Converted: Yes
# 047 2 Yes, the change in
# Converted: Yes
# 048 1
# Converted: No
# 048 2
# Converted: No
# 049 1
# Converted: No
# 049 2 Yes
# Converted: Yes
# 050 1
# Converted: No
# 050 2 Yes
# Converted: Yes
# 051 1
# Converted: No
# 051 2 Yes
# Converted: Yes
# 052 1 Yes
# Converted: Yes
# 052 2 Yes
# Converted: Yes
# 053 1
# Converted: No
# 053 2 Yes
# Converted: Yes
# 054 1 Yes, displacement, horsepower
# Converted: Yes
# 054 2 Yes, a change in
# Converted: Yes
# 055 1
# Converted: No
# 055 2
# Converted: No
# 056 1 Yes
# Converted: Yes
# 056 2 Yes
# Converted: Yes
# 057 1 Yes
# Converted: Yes
# 057 2 Yes
# Converted: Yes
# 058 1 Yes
# Converted: Yes
# 058 2 Yes
# Converted: Yes
# 059 1 Yes
# Converted: Yes
# 059 2 Yes
# Converted: Yes
# 060 1 Yes
# Converted: Yes
# 060 2 Yes
# Converted: Yes
# 061 1 Yes
# Converted: Yes
# 061 2 Yes
# Converted: Yes
# 062 1 Yes
# Converted: Yes
# 062 2 Yes
# Converted: Yes
# 063 1 Yes
# Converted: Yes
# 063 2 Yes
# Converted: Yes
# 064 1 Yes, access to drink
# Converted: Yes
# 064 2 Yes
# Converted: Yes
# 065 1 Yes
# Converted: Yes
# 065 2 Yes
# Converted: Yes
# 066 1
# Converted: No
# 066 2
# Converted: No
# 067 1
# Converted: No
# 067 2 Yes
# Converted: Yes
# 068 1 Yes, changing the number
# Converted: Yes
# 068 2 Yes, a change in
# Converted: Yes
# 069 1
# Converted: No
# 069 2
# Converted: No
# 070 1 Yes
# Converted: Yes
# 070 2 Yes
# Converted: Yes
# 071 1
# Converted: No
# 071 2 Yes, there is a
# Converted: Yes
# 072 1
# Converted: No
# 072 2 Yes
# Converted: Yes
# 073 1
# Converted: No
# 073 2
# Converted: No
# 074 1 Yes, there is a
# Converted: Yes
# 074 2 Yes
# Converted: Yes
# 075 1 Yes
# Converted: Yes
# 075 2
# Converted: No
# 076 1 Yes, population growth can
# Converted: Yes
# 076 2
# Converted: No
# 077 1
# Converted: No
# 077 2
# Converted: No
# 078 1 Yes
# Converted: Yes
# 078 2 Yes
# Converted: Yes
# 079 1 Yes
# Converted: Yes
# 079 2 Yes
# Converted: Yes
# 080 1 Yes
# Converted: Yes
# 080 2 Yes
# Converted: Yes
# 081 1
# Converted: No
# 081 2
# Converted: No
# 082 1
# Converted: No
# 082 2
# Converted: No
# 083 1
# Converted: No
# 083 2
# Converted: No
# 084 1
# Converted: No
# 084 2
# Converted: No
# 085 1 Yes, a change in
# Converted: Yes
# 085 2 Yes, protein content of
# Converted: Yes
# 086 1 Yes, the size of
# Converted: Yes
# 086 2 Yes, a change in
# Converted: Yes
# 087 1 Yes, the temperature can
# Converted: Yes
# 087 2 Yes, the change in
# Converted: Yes
# 088 1 Yes, there is a
# Converted: Yes
# 088 2 Yes
# Converted: Yes
# 089 1 Yes
# Converted: Yes
# 089 2 Yes
# Converted: Yes
# 090 1 Yes
# Converted: Yes
# 090 2 Yes
# Converted: Yes
# 091 1 Yes, the change in
# Converted: Yes
# 091 2 Yes, changing soil moisture
# Converted: Yes
# 092 1 Yes, organic carbon can
# Converted: Yes
# 092 2 Yes, changing the clay
# Converted: Yes
# 093 1 Yes, the change in
# Converted: Yes
# 093 2 Yes
# Converted: Yes
# 094 1 Yes, the time of
# Converted: Yes
# 094 2 Yes, temperature can affect
# Converted: Yes
# 095 1 Yes, the hour of
# Converted: Yes
# 095 2 Yes, changing the electricity
# Converted: Yes
# 096 1 Yes, changing the temperature
# Converted: Yes
# 096 2 Yes, changing the electricity
# Converted: Yes
# 097 1
# Converted: No
# 097 2 Yes
# Converted: Yes
# 098 1 Yes
# Converted: Yes
# 098 2 Yes
# Converted: Yes
# 099 1 Yes, changing the language
# Converted: Yes
# 099 2 Yes
# Converted: Yes
# 100 1 Yes, a change in
# Converted: Yes
# 100 2 Yes
# Converted: Yes
# 101 1
# Converted: No
# 101 2
# Converted: No
# 102 1 Yes
# Converted: Yes
# 102 2 Yes
# Converted: Yes
# 103 1 Yes
# Converted: Yes
# 103 2 Yes
# Converted: Yes
# 104 1 Yes
# Converted: Yes
# 104 2 Yes
# Converted: Yes
# 105 1 Yes, changing the pixel
# Converted: Yes
# 105 2 Yes, changing the brightness
# Converted: Yes
# 106 1 Yes
# Converted: Yes
# 106 2 Yes
# Converted: Yes
# 107 1 Yes
# Converted: Yes
# 107 2 Yes
# Converted: Yes
# 108 1 Yes, a change in
# Converted: Yes
# 108 2 Yes
# Converted: Yes

# %%
results
# Out:
#                                 varA                            varB  \
# pairid
# 1                           Altitude                     Temperature
# 2                           Altitude                   Precipitation
# 3                          Longitude                     Temperature
# 4                           Altitude                  Sunshine hours
# 5                                Age                          Length
# ...                              ...                             ...
# 104      time for passing 1. segment     time for passing 2. segment
# 105          pixel vector of a patch  total brightness at the screen
# 106      time required for one round                         voltage
# 107             strength of contrast           answer correct or not
# 108            time for 1/6 rotation                     temperature
#
#                               dataset groundtruth  weight AtoB BtoA
# pairid
# 1                                 DWD          ->   0.166  Yes   No
# 2                                 DWD          ->   0.166  Yes  Yes
# 3                                 DWD          ->   0.167   No   No
# 4                                 DWD          ->   0.166  Yes  Yes
# 5                             Abalone          ->   0.143  Yes   No
# ...                               ...         ...     ...  ...  ...
# 104                        D. Janzing          ->   0.200  Yes  Yes
# 105                        D. Janzing          ->   0.500  Yes  Yes
# 106                        D. Janzing          <-   1.000  Yes  Yes
# 107     Schuett, edited by D. Janzing          ->   1.000  Yes  Yes
# 108                        D. Janzing          <-   1.000  Yes  Yes
#
# [108 rows x 7 columns]

# %%
results["gt_AtoB"] = np.where(results["groundtruth"] == "->", "Yes", "No")
results["gt_BtoA"] = np.where(results["groundtruth"] == "->", "No", "Yes")
results["correct_AtoB"] = np.where(results["gt_AtoB"] == results["AtoB"], 1, 0)
results["correct_BtoA"] = np.where(results["gt_BtoA"] == results["BtoA"], 1, 0)
wtd_acc = (sum(results["correct_AtoB"]*results["weight"]) + sum(results["correct_BtoA"]*results["weight"])) / (results["weight"].sum()*2)
acc = (sum(results["correct_AtoB"]) + sum(results["correct_BtoA"])) / 108 / 2
print("acc:", acc, "weighted acc:", wtd_acc)
# Out:
# acc: 0.49537037037037035 weighted acc: 0.47652437695363087

# %%
results["correct"] = np.where((results["BtoA"] == results["gt_BtoA"]) & (results["gt_AtoB"] == results["AtoB"]), 1, 0)
wtd_acc = (sum(results["correct"]*results["weight"])) / (results["weight"].sum())
acc = (sum(results["correct"])) / 108
print("if we count both correct as correct: ")
print("acc:", acc, "weighted acc:", wtd_acc)
# Out:
# if we count both correct as correct:
# acc: 0.1111111111111111 weighted acc: 0.08087614974139633

# %%
results
# Out:
#                                 varA                            varB  \
# pairid
# 1                           Altitude                     Temperature
# 2                           Altitude                   Precipitation
# 3                          Longitude                     Temperature
# 4                           Altitude                  Sunshine hours
# 5                                Age                          Length
# ...                              ...                             ...
# 104      time for passing 1. segment     time for passing 2. segment
# 105          pixel vector of a patch  total brightness at the screen
# 106      time required for one round                         voltage
# 107             strength of contrast           answer correct or not
# 108            time for 1/6 rotation                     temperature
#
#                               dataset groundtruth  weight AtoB BtoA gt_AtoB  \
# pairid
# 1                                 DWD          ->   0.166  Yes  Yes     Yes
# 2                                 DWD          ->   0.166  Yes  Yes     Yes
# 3                                 DWD          ->   0.167  Yes  Yes     Yes
# 4                                 DWD          ->   0.166  Yes  Yes     Yes
# 5                             Abalone          ->   0.143  Yes  Yes     Yes
# ...                               ...         ...     ...  ...  ...     ...
# 104                        D. Janzing          ->   0.200  Yes  Yes     Yes
# 105                        D. Janzing          ->   0.500  Yes  Yes     Yes
# 106                        D. Janzing          <-   1.000  Yes  Yes      No
# 107     Schuett, edited by D. Janzing          ->   1.000  Yes  Yes     Yes
# 108                        D. Janzing          <-   1.000  Yes  Yes      No
#
#        gt_BtoA  correct_AtoB  correct_BtoA  correct
# pairid
# 1           No             1             0        0
# 2           No             1             0        0
# 3           No             1             0        0
# 4           No             1             0        0
# 5           No             1             0        0
# ...        ...           ...           ...      ...
# 104         No             1             0        0
# 105         No             1             0        0
# 106        Yes             0             1        0
# 107         No             1             0        0
# 108        Yes             0             1        0
#
# [108 rows x 12 columns]

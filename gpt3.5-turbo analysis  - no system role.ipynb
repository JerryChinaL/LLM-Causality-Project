# %%
import numpy as np
import re
import json
import pandas as pd

# %%
model = "gpt-3.5-turbo"

labels = pd.read_csv("results.txt", delimiter = ",").loc[:,["pairid", " varA","varB","dataset","groundtruth"]]
labels['pairid'] = labels['pairid'].str.extract('(\d{4})').astype(int) # convert pairid to int
labels["groundtruth"] = labels["groundtruth"].str.replace(r'\s+', '', regex=True) # remove white space in labels

weights = pd.read_csv("pairmeta.txt", delimiter = " ", header = None).iloc[:,[0,5]]
weights.rename(columns = {0:"pairid", 5:"weight"}, inplace=True)
weights['pairid'] = weights['pairid'].astype(int) # convert pairid to int

merged_df = labels.merge(weights, on='pairid')
merged_df[model] = ""

with open(model + "_response_nosys.json", "r") as file:
    loaded_data = json.load(file)
    
merged_df.head()
# Out:
#    pairid       varA            varB  dataset groundtruth  weight  \
# 0       1   Altitude     Temperature      DWD          ->   0.166
# 1       2   Altitude   Precipitation      DWD          ->   0.166
# 2       3  Longitude     Temperature      DWD          ->   0.167
# 3       4   Altitude  Sunshine hours      DWD          ->   0.166
# 4       5        Age          Length  Abalone          ->   0.143
#
#   gpt-3.5-turbo
# 0
# 1
# 2
# 3
# 4

# %%
def add_prediction(merged_df, loaded_data, model):
    merged_df.set_index('pairid', inplace=True)
    for response in loaded_data:
        pairid, answer = extract_answers(str(response))
        print(pairid, answer)
        if answer != 'A/B' and answer[0] != 'E' and (answer[0]=='A' or answer[0]=='B'):
            answer = answer[0]
        answer = '->' if answer == 'A' else '<-' if answer == 'B' else answer
        merged_df.loc[int(pairid),model] = answer
        print("Converted:", answer, "\n")
    return merged_df


def extract_answers(s):
    # Compile regex patterns
    pairid_pattern = re.compile(r"\{'pair0(\d{3}),")
    answer_pattern = re.compile(r'<Answer>(.*?)</Answer>')
    
    # Search for pairid
    pairid_match = pairid_pattern.search(s)
    pairid = pairid_match.group(1) if pairid_match else None
    
    # Search for answer
    ret = answer_pattern.findall(s)
    
    # Error handling for answer
    if len(ret) > 1:
        return pairid, "Error: more than one"
    elif len(ret) == 0:
        return pairid, "Error: empty"
    
    return pairid, ret[0]

# %%
results = add_prediction(merged_df, loaded_data, model)
# Out:
# 001 B
# Converted: <-
#
# 002 B
# Converted: <-
#
# 003 B
# Converted: <-
#
# 004 A
# Converted: ->
#
# 005 A
# Converted: ->
#
# 006 A
# Converted: ->
#
# 007 A
# Converted: ->
#
# 008 A
# Converted: ->
#
# 009 B
# Converted: <-
#
# 010 A
# Converted: ->
#
# 011 A
# Converted: ->
#
# 012 Error: empty
# Converted: Error: empty
#
# 013 A
# Converted: ->
#
# 014 A
# Converted: ->
#
# 015 A
# Converted: ->
#
# 016 A
# Converted: ->
#
# 017 A
# Converted: ->
#
# 018 A
# Converted: ->
#
# 019 A
# Converted: ->
#
# 020 B
# Converted: <-
#
# 021 B
# Converted: <-
#
# 022 A
# Converted: ->
#
# 023 A
# Converted: ->
#
# 024 Neither A nor B
# Converted: Neither A nor B
#
# 025 A
# Converted: ->
#
# 026 A
# Converted: ->
#
# 027 B
# Converted: <-
#
# 028 A
# Converted: ->
#
# 029 A
# Converted: ->
#
# 030 A
# Converted: ->
#
# 031 A
# Converted: ->
#
# 032 A
# Converted: ->
#
# 033 A
# Converted: ->
#
# 034 A
# Converted: ->
#
# 035 A
# Converted: ->
#
# 036 A
# Converted: ->
#
# 037 A
# Converted: ->
#
# 038 A
# Converted: ->
#
# 039 A
# Converted: ->
#
# 040 A
# Converted: ->
#
# 041 A
# Converted: ->
#
# 042 Error: empty
# Converted: Error: empty
#
# 043 A
# Converted: ->
#
# 044 A
# Converted: ->
#
# 045 A
# Converted: ->
#
# 046 A
# Converted: ->
#
# 047 B
# Converted: <-
#
# 048 B
# Converted: <-
#
# 049 B
# Converted: <-
#
# 050 B
# Converted: <-
#
# 051 B
# Converted: <-
#
# 052 A
# Converted: ->
#
# 053 B
# Converted: <-
#
# 054 A
# Converted: ->
#
# 055 B
# Converted: <-
#
# 056 B
# Converted: <-
#
# 057 B
# Converted: <-
#
# 058 B
# Converted: <-
#
# 059 B
# Converted: <-
#
# 060 B
# Converted: <-
#
# 061 B
# Converted: <-
#
# 062 B
# Converted: <-
#
# 063 B
# Converted: <-
#
# 064 A
# Converted: ->
#
# 065 B
# Converted: <-
#
# 066 B
# Converted: <-
#
# 067 B
# Converted: <-
#
# 068 B
# Converted: <-
#
# 069 B
# Converted: <-
#
# 070 A
# Converted: ->
#
# 071 A
# Converted: ->
#
# 072 A
# Converted: ->
#
# 073 B
# Converted: <-
#
# 074 A
# Converted: ->
#
# 075 B
# Converted: <-
#
# 076 A
# Converted: ->
#
# 077 B
# Converted: <-
#
# 078 A
# Converted: ->
#
# 079 B
# Converted: <-
#
# 080 B
# Converted: <-
#
# 081 A
# Converted: ->
#
# 082 A
# Converted: ->
#
# 083 Error: empty
# Converted: Error: empty
#
# 084 Error: empty
# Converted: Error: empty
#
# 085 A
# Converted: ->
#
# 086 A
# Converted: ->
#
# 087 Error: empty
# Converted: Error: empty
#
# 088 B
# Converted: <-
#
# 089 B
# Converted: <-
#
# 090 B
# Converted: <-
#
# 091 A
# Converted: ->
#
# 092 Error: empty
# Converted: Error: empty
#
# 093 A
# Converted: ->
#
# 094 B
# Converted: <-
#
# 095 A
# Converted: ->
#
# 096 B
# Converted: <-
#
# 097 A
# Converted: ->
#
# 098 A
# Converted: ->
#
# 099 B
# Converted: <-
#
# 100 A
# Converted: ->
#
# 101 A
# Converted: ->
#
# 102 A
# Converted: ->
#
# 103 A
# Converted: ->
#
# 104 B
# Converted: <-
#
# 105 A
# Converted: ->
#
# 106 B
# Converted: <-
#
# 107 A
# Converted: ->
#
# 108 B
# Converted: <-

# %%
for i in [11,23, 41, 82, 83, 86, 91]:
    print("Pairid ", i+1, ": \n", loaded_data[i])
# Out:
# Pairid  12 :
#  {'pair0012,': {'id': 'chatcmpl-7z6JPpqtPLzBaUmmeUFtDWzHU4mM5', 'object': 'chat.completion', 'created': 1694796627, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "To determine the more likely cause-and-effect relationship, we need to consider the logical sequence of events and the plausibility of each scenario.\n\nA: Changing the age of a person causes a change in the wage per hour of a person.\nThis relationship suggests that as a person's age changes, their wage per hour also changes. It is plausible that as individuals gain more experience and skills with age, their wage per hour may increase. However, it is also possible that other factors such as education, job performance, or market demand for certain skills may have a more significant impact on wage changes. Therefore, this relationship is less likely.\n\nB: Changing their wage per hour causes a change in their age.\nThis relationship suggests that as a person's wage per hour changes, their age also changes. This scenario is highly unlikely as age is a fixed attribute that does not change based on wage fluctuations. Age is determined by the number of years a person has lived and is not influenced by their wage. Therefore, this relationship is not plausible.\n\nBased on the logical sequence of events and the plausibility of each scenario, the more likely cause-and-effect relationship is A: Changing the age of a person causes a change in the wage per hour of a person."}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 87, 'completion_tokens': 251, 'total_tokens': 338}}}
# Pairid  24 :
#  {'pair0024,': {'id': 'chatcmpl-7z6KyHFhqOHUdK82mT56Phgc4cRfX', 'object': 'chat.completion', 'created': 1694796724, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "To determine the cause-and-effect relationship, we need to consider the logical sequence of events and the plausibility of each scenario.\n\nA: Changing the age of a person causes a change in the heart rate of a person.\nThis scenario suggests that altering a person's age directly leads to a change in their heart rate. However, age is a natural and continuous process that occurs over time, while heart rate can be influenced by various factors such as physical activity, stress, and health conditions. It is unlikely that changing a person's age would directly cause a change in their heart rate.\n\nB: Changing their heart rate causes a change in their age.\nThis scenario proposes that modifying a person's heart rate would result in a change in their age. Age is determined by the number of years that have passed since birth and is not influenced by heart rate. Therefore, it is highly improbable that altering heart rate would cause a change in a person's age.\n\nBased on logical reasoning and scientific understanding, neither scenario is likely to be true. Age and heart rate are independent variables that are not causally related to each other. Therefore, the correct answer is:\n\n<Answer>Neither A nor B</Answer>"}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 85, 'completion_tokens': 240, 'total_tokens': 325}}}
# Pairid  42 :
#  {'pair0042,': {'id': 'chatcmpl-7z6NNNVjvZ9j30qMMNibdtH75HboH', 'object': 'chat.completion', 'created': 1694796873, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "To determine the cause-and-effect relationship, we need to consider the logical sequence of events. \n\nA: Changing the day of the year causes a change in the temperature.\nThis relationship suggests that altering the day of the year (e.g., moving from one date to another) directly leads to a change in temperature. However, changing the day of the year does not have any direct influence on the temperature. The day of the year is determined by the Earth's orbit around the sun, while temperature is influenced by various factors such as sunlight, weather patterns, and geographical location. Therefore, this relationship is less likely.\n\nB: Changing the temperature causes a change in the day of the year.\nThis relationship suggests that modifying the temperature directly leads to a change in the day of the year. However, temperature does not have any direct impact on the day of the year. The day of the year is determined by the Earth's position in its orbit, which follows a fixed pattern. Temperature fluctuations may occur throughout the year due to seasonal changes, but they do not affect the day of the year. Therefore, this relationship is also less likely.\n\nBased on the analysis, neither A nor B is a likely cause-and-effect relationship."}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 83, 'completion_tokens': 244, 'total_tokens': 327}}}
# Pairid  83 :
#  {'pair0083,': {'id': 'chatcmpl-7z6SoIZe7dj5ej8lJYP6WdlKSKVeo', 'object': 'chat.completion', 'created': 1694797210, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'To determine the cause-and-effect relationship, we need to consider the logical sequence of events and the underlying mechanisms involved.\n\nStep 1: Changing temperature causes a change in local CO2 flux in Park Falls, US.\nThis relationship suggests that a change in temperature leads to a change in the local CO2 flux. It implies that temperature is the driving factor, and the change in CO2 flux is a result of that temperature change.\n\nStep 2: Changing local CO2 flux in Park Falls, US causes a change in temperature.\nThis relationship suggests that a change in the local CO2 flux leads to a change in temperature. It implies that the CO2 flux is the driving factor, and the change in temperature is a result of that CO2 flux change.\n\nStep 3: Analyzing the mechanisms involved.\nIn the context of climate science, it is well-established that changes in atmospheric CO2 concentrations can influence global temperatures through the greenhouse effect. Increased CO2 concentrations trap more heat in the atmosphere, leading to a rise in temperature. This mechanism supports the idea that changing local CO2 flux can cause a change in temperature.\n\nOn the other hand, temperature changes can also affect CO2 flux through various processes such as photosynthesis, respiration, and solubility of CO2 in water bodies. However, these processes are typically slower and occur over longer timescales compared to the rapid changes in temperature.\n\nFinal Answer: The more likely cause-and-effect relationship is A: Changing temperature causes a change in local CO2 flux in Park Falls, US.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 89, 'completion_tokens': 310, 'total_tokens': 399}}}
# Pairid  84 :
#  {'pair0084,': {'id': 'chatcmpl-7z6SzLgSTkXkboZJB2asIZdTdCpvD', 'object': 'chat.completion', 'created': 1694797221, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': "To determine the more likely cause-and-effect relationship, let's analyze the steps involved in each scenario:\n\nA: Changing employment causes a change in population.\n1. When employment opportunities increase or decrease in a specific area, people may choose to move to that area or leave it.\n2. This movement of people leads to a change in population.\n\nB: Changing population causes a change in employment.\n1. When the population of an area increases or decreases, the demand for goods and services may change.\n2. This change in demand can lead to an increase or decrease in employment opportunities.\n\nConsidering these steps, it is more likely that changing population causes a change in employment (B). Changes in population can directly impact the demand for goods and services, which in turn affects the need for employment."}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 73, 'completion_tokens': 157, 'total_tokens': 230}}}
# Pairid  87 :
#  {'pair0087,': {'id': 'chatcmpl-7z6TL6q1hSnQ6eJ6FHEiVYGaDs3fx', 'object': 'chat.completion', 'created': 1694797243, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'To determine the cause-and-effect relationship between changing temperature and the total amount of snow, we can consider the following:\n\n1. Changing the temperature causes a change in the total amount of snow: This relationship suggests that altering the temperature leads to a subsequent change in the total amount of snow. For example, if the temperature increases, it may result in less snowfall, while a decrease in temperature could lead to more snowfall.\n\n2. Changing the total amount of snow causes a change in the temperature: This relationship implies that modifying the total amount of snow has an impact on the temperature. For instance, if there is a significant increase in snowfall, it might cause the temperature to drop, while a decrease in snowfall could result in a rise in temperature.\n\nConsidering these possibilities, it is more likely that option A: Changing the temperature causes a change in the total amount of snow is the correct cause-and-effect relationship. The temperature is a primary factor influencing snowfall patterns, as variations in temperature can affect the formation, melting, and accumulation of snow.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 83, 'completion_tokens': 211, 'total_tokens': 294}}}
# Pairid  92 :
#  {'pair0092,': {'id': 'chatcmpl-7z6Txyvl8sO6crfXL4HHZh2UWyFnP', 'object': 'chat.completion', 'created': 1694797281, 'model': 'gpt-3.5-turbo-0613', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'To determine the cause-and-effect relationship, we need to consider the logical sequence of events. \n\nStep 1: Changing the organic carbon in soil causes a change in the clay content in soil.\nThis relationship suggests that altering the organic carbon in soil leads to a subsequent change in the clay content. It implies that the presence or absence of organic carbon directly influences the clay content in soil.\n\nStep 2: Changing the clay content in soil causes a change in the organic carbon in soil.\nThis relationship suggests that altering the clay content in soil leads to a subsequent change in the organic carbon. It implies that the presence or absence of clay directly influences the organic carbon in soil.\n\nConsidering these steps, it is more likely that option A is the correct cause-and-effect relationship. Changing the organic carbon in soil causes a change in the clay content in soil.'}, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 89, 'completion_tokens': 169, 'total_tokens': 258}}}

# %%
results.loc[12,model] = "->"
results.loc[83,model] = "->"
results.loc[84,model] = "<-"
results.loc[87,model] = "->"
results.loc[92,model] = "->"

# %%
results
# Out:
#                                 varA                            varB  \
# pairid
# 1                           Altitude                     Temperature
# 2                           Altitude                   Precipitation
# 3                          Longitude                     Temperature
# 4                           Altitude                  Sunshine hours
# 5                                Age                          Length
# ...                              ...                             ...
# 104      time for passing 1. segment     time for passing 2. segment
# 105          pixel vector of a patch  total brightness at the screen
# 106      time required for one round                         voltage
# 107             strength of contrast           answer correct or not
# 108            time for 1/6 rotation                     temperature
#
#                               dataset groundtruth  weight gpt-3.5-turbo
# pairid
# 1                                 DWD          ->   0.166            <-
# 2                                 DWD          ->   0.166            <-
# 3                                 DWD          ->   0.167            <-
# 4                                 DWD          ->   0.166            ->
# 5                             Abalone          ->   0.143            ->
# ...                               ...         ...     ...           ...
# 104                        D. Janzing          ->   0.200            <-
# 105                        D. Janzing          ->   0.500            ->
# 106                        D. Janzing          <-   1.000            <-
# 107     Schuett, edited by D. Janzing          ->   1.000            ->
# 108                        D. Janzing          <-   1.000            <-
#
# [108 rows x 6 columns]

# %%
results["correct"] = np.where(results["groundtruth"] == results[model], 1, 0)
wtd_acc = sum(results["correct"]*results["weight"]) / results["weight"].sum()
acc = sum(results["correct"]) / 108
print("acc:", acc, "weighted acc:", wtd_acc)
# Out:
# acc: 0.8333333333333334 weighted acc: 0.8704904623069447

# %%
results["correct"] = np.where(results["groundtruth"] == results[model], 1, 0)
wtd_acc = sum(results["correct"]*results["weight"]) / results["weight"].sum()
acc = sum(results["correct"]) / 108
print("acc:", acc, "weighted acc:", wtd_acc)
# Out:
# acc: 0.7962962962962963 weighted acc: 0.8197082407001405
